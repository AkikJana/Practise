# %%
import pandas

# %%
tq=pandas.read_csv("SurveySchema.csv")
tq
# Out:
#    2018 Kaggle Machine Learning and Data Science Survey  \
# 0                                           Question:
# 1                                   # of Respondents:
# 2   Who was excluded? (0 = not excluded; 1 = exclu...
# 3   If What is your age (# years)? 0-17 Is Selecte...
# 4   If What is the highest level of formal educati...
# 5   If Select the title most similar to your curre...
# 6   Or How long have you been writing code to anal...
# 7   If How do you perceive the importance of the f...
# 8   If How do you perceive the importance of the f...
# 9   If How do you perceive the importance of the f...
# 10  If Which of the following cloud computing serv...
# 11  If On which online platforms have you begun or...
#
#                                         Q1  \
# 0   What is your gender? - Selected Choice
# 1                                    23860
# 2                                        0
# 3                                        0
# ...
